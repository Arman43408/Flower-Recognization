# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import os
import keras

# %%
base_dir = 'flowers/'

img_size = 224
batch = 64

# %%
# Create a data augmentor
train_datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2,zoom_range=0.2, horizontal_flip=True,validation_split=0.2)

test_datagen = ImageDataGenerator(rescale=1. / 255,validation_split=0.2)

# Create datasets
train_datagen = train_datagen.flow_from_directory(base_dir,target_size=(img_size, img_size),subset='training',batch_size=batch)
test_datagen = test_datagen.flow_from_directory(base_dir,target_size=(img_size, img_size),subset='validation',batch_size=batch)
# Out:
# Found 3457 images belonging to 5 classes.
# Found 860 images belonging to 5 classes.

# %%
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters=64, kernel_size=(5, 5), padding='same',activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(filters=64, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


model.add(Conv2D(filters=64, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      4864
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 6541253 (24.95 MB)
# Trainable params: 6541253 (24.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes = True,show_dtype = True,show_layer_activations = True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),loss='categorical_crossentropy', metrics=['accuracy'])

# %%
epochs=30
model.fit(train_datagen,epochs=epochs,validation_data=test_datagen)
# Out:
# Epoch 1/30
# 55/55 [==============================] - 216s 4s/step - loss: 1.3809 - accuracy: 0.4030 - val_loss: 1.2196 - val_accuracy: 0.5221
# Epoch 2/30
# 55/55 [==============================] - 194s 4s/step - loss: 1.0969 - accuracy: 0.5586 - val_loss: 1.0689 - val_accuracy: 0.5674
# Epoch 3/30
# 55/55 [==============================] - 200s 4s/step - loss: 1.0291 - accuracy: 0.5959 - val_loss: 0.9947 - val_accuracy: 0.6140
# Epoch 4/30
# 55/55 [==============================] - 193s 3s/step - loss: 0.9347 - accuracy: 0.6309 - val_loss: 0.9301 - val_accuracy: 0.6512
# Epoch 5/30
# 55/55 [==============================] - 204s 4s/step - loss: 0.8768 - accuracy: 0.6595 - val_loss: 0.8893 - val_accuracy: 0.6558
# Epoch 6/30
# 55/55 [==============================] - 208s 4s/step - loss: 0.8819 - accuracy: 0.6627 - val_loss: 0.9909 - val_accuracy: 0.6000
# Epoch 7/30
# 55/55 [==============================] - 210s 4s/step - loss: 0.8475 - accuracy: 0.6731 - val_loss: 0.8485 - val_accuracy: 0.6744
# Epoch 8/30
# 55/55 [==============================] - 211s 4s/step - loss: 0.7266 - accuracy: 0.7266 - val_loss: 0.8872 - val_accuracy: 0.6547
# Epoch 9/30
# 55/55 [==============================] - 214s 4s/step - loss: 0.6837 - accuracy: 0.7408 - val_loss: 0.8686 - val_accuracy: 0.6686
# Epoch 10/30
# 55/55 [==============================] - 216s 4s/step - loss: 0.7904 - accuracy: 0.6983 - val_loss: 0.8822 - val_accuracy: 0.6640
# Epoch 11/30
# 55/55 [==============================] - 219s 4s/step - loss: 0.7572 - accuracy: 0.7159 - val_loss: 0.8884 - val_accuracy: 0.6814
# Epoch 12/30
# 55/55 [==============================] - 229s 4s/step - loss: 0.6815 - accuracy: 0.7373 - val_loss: 0.8767 - val_accuracy: 0.6907
# Epoch 13/30
# 55/55 [==============================] - 219s 4s/step - loss: 0.7128 - accuracy: 0.7324 - val_loss: 0.8438 - val_accuracy: 0.7012
# Epoch 14/30
# 55/55 [==============================] - 217s 4s/step - loss: 0.6094 - accuracy: 0.7732 - val_loss: 0.8433 - val_accuracy: 0.6977
# Epoch 15/30
# 55/55 [==============================] - 222s 4s/step - loss: 0.5224 - accuracy: 0.8036 - val_loss: 0.8109 - val_accuracy: 0.7174
# Epoch 16/30
# 55/55 [==============================] - 224s 4s/step - loss: 0.4708 - accuracy: 0.8282 - val_loss: 0.9311 - val_accuracy: 0.6977
# Epoch 17/30
# 55/55 [==============================] - 222s 4s/step - loss: 0.5471 - accuracy: 0.8053 - val_loss: 0.8444 - val_accuracy: 0.6895
# Epoch 18/30
# 55/55 [==============================] - 225s 4s/step - loss: 0.4451 - accuracy: 0.8314 - val_loss: 0.9490 - val_accuracy: 0.7093
# Epoch 19/30
# 55/55 [==============================] - 219s 4s/step - loss: 0.3908 - accuracy: 0.8565 - val_loss: 1.0054 - val_accuracy: 0.6895
# Epoch 20/30
# 55/55 [==============================] - 226s 4s/step - loss: 0.3172 - accuracy: 0.8898 - val_loss: 1.0357 - val_accuracy: 0.7058
# Epoch 21/30
# 55/55 [==============================] - 220s 4s/step - loss: 0.3951 - accuracy: 0.8557 - val_loss: 1.1610 - val_accuracy: 0.6919
# Epoch 22/30
# 55/55 [==============================] - 221s 4s/step - loss: 0.3139 - accuracy: 0.8881 - val_loss: 1.1553 - val_accuracy: 0.6977
# Epoch 23/30
# 55/55 [==============================] - 221s 4s/step - loss: 0.2659 - accuracy: 0.8996 - val_loss: 1.2125 - val_accuracy: 0.7081
# Epoch 24/30
# 55/55 [==============================] - 233s 4s/step - loss: 0.2590 - accuracy: 0.9124 - val_loss: 1.2115 - val_accuracy: 0.7163
# Epoch 25/30
# 55/55 [==============================] - 210s 4s/step - loss: 0.2192 - accuracy: 0.9245 - val_loss: 1.2242 - val_accuracy: 0.7151
# Epoch 26/30
# 55/55 [==============================] - 222s 4s/step - loss: 0.2088 - accuracy: 0.9274 - val_loss: 1.2302 - val_accuracy: 0.6965
# Epoch 27/30
# 55/55 [==============================] - 229s 4s/step - loss: 0.1634 - accuracy: 0.9459 - val_loss: 1.3461 - val_accuracy: 0.7198
# Epoch 28/30
# 55/55 [==============================] - 236s 4s/step - loss: 0.1404 - accuracy: 0.9552 - val_loss: 1.4451 - val_accuracy: 0.7000
# Epoch 29/30
# 55/55 [==============================] - 237s 4s/step - loss: 0.1199 - accuracy: 0.9621 - val_loss: 1.3661 - val_accuracy: 0.7279
# Epoch 30/30
# 55/55 [==============================] - 234s 4s/step - loss: 0.1124 - accuracy: 0.9572 - val_loss: 1.6160 - val_accuracy: 0.7035

# %%
from tensorflow.keras.models import load_model
model.save('Model.h5')

# load model
savedModel=load_model('Model.h5')
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
train_datagen.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
from keras.preprocessing import image

#Creating list for mapping
list_ = ['Daisy','Danelion','Rose','sunflower', 'tulip']

#Input image
test_image = image.load_img('img.jpg',target_size=(224,224))

#For show image
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)

# Result array
result = savedModel.predict(test_image)
print(result)

#Mapping result array with the main name list
i=0
for i in range(len(result[0])):
 if(result[0][i]==1):
    print(list_[i])
    break
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [[1. 0. 0. 0. 0.]]
# Daisy

# %%
#Input image
test_image = image.load_img('img2.jpg',target_size=(224,224))

#For show image
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)

# Result array
result = savedModel.predict(test_image)
print(result)

#Mapping result array with the main name list
i=0
for i in range(len(result[0])):
 if(result[0][i]==1):
    print(list_[i])
    break
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[0. 0. 0. 0. 1.]]
# tulip
